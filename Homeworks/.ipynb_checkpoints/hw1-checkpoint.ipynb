# %%
#imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## 2.4.1

# %% [markdown]
# For each of parts (a) through (d), indicate whether we would generally expect the performance of a flexible statistical learning method to be better or worse than an inflexible method. Justify your answer.
#
# (a) The sample size n is extremely large, and the number of predictors p is small.
# Flexible statistical learning method will be expected to perform better. We have a larger sample size, which helps the model learn better. There are a small number of predictors which lessens the risk of overfitting.
#
# (b) The number of predictors p is extremely large, and the number of observations n is small.
# Inflexible statistical learning method will be expected to perform better. A smaller sample size means there may be a large risk of bias if we use a flexible statistical learning method. The large number of predictors may cause a flexible statistical method to overfit. An inflexible statistical learning method will help avoid these since it could reach a better model faster.
#
# (c) The relationship between the predictors and response is highly non-linear.
# A flexible statistical learning method will be better since it can adapt itself to the non-linear data better than the inflexible method. Inflexible methods will try to warp the observations to its own idea of the model,  for example a best fit linear model.
#
#
# (d) The variance of the error terms, i.e. σ2 = Var("), is extremely high.
# An inflexible statistical learning method will be better. A flexible method would try to incorporate the extra noise/ error terms into its model, and give an inaccurate model.

# %% [markdown]
# ## 2.4.3

# %% [markdown]
# We now revisit the bias-variance decomposition.
#
# (a) Provide a sketch of typical (squared) bias, variance, training error, test error, and Bayes (or irreducible) error curves, on a single plot, as we go from less flexible statistical learning methods towards more flexible approaches. The x-axis should represent the amount of flexibility in the method, and the y-axis should represent the values for each curve. There should be five curves. Make sure to label each one.

# %%
#this is taken from https://botlnec.github.io/islp/sols/chapter2/exercise3/

import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0.0, 10.0, 0.02)

def squared_bias(x):
    return .002*(-x+10)**3
def variance(x):
    return .002*x**3 
def training_error(x):
    return 2.38936 - 0.825077*x + 0.176655*x**2 - 0.0182319*x**3 + 0.00067091*x**4
def test_error(x):
    return 3 - 0.6*x + .06*x**2
def bayes_error(x):
    return x + 1 - x

plt.xkcd()
#frame = plt.gca()
#frame.axes.xaxis.set_ticklabels([])
plt.figure(figsize=(10, 8))
plt.plot(x,squared_bias(x), label='squared bias')
plt.plot(x, variance(x), label='variance')
plt.plot(x, training_error(x), label='training error')
plt.plot(x, test_error(x), label='test error')
plt.plot(x, bayes_error(x), label='Bayes error')
plt.legend(loc='upper center')
plt.xlabel('model flexibility')
plt.show()

#arbitrary units

# %% [markdown]
# (b) Explain why each of the five curves has the shape displayed in part (a). typical (squared) bias, variance, training error, test error, and Bayes (or irreducible) error curves
#
# Typical squared bias: As the model becomes more flexible, it can adapt more to the data and reduce the quantity of typical (squared) bias.
#
# Variance: The variance increases as the flexibility increases. This is because as the model becomes more flexible it captures more and more of the noise in the data, which increases variance.
#
# Training error: The training error decreases as flexibility increases. As the model becomes more flexible, it captures the data better (to the point of overfitting) and so the predictions will not be far from the observations. This decreases training error.
#
# Test error: The test error has a parabolic shape with a minimum. This is found by adding the variance, Bayes error and squared bias. When either variance or squared bias is decreasing, the other increases significantly. Bayes error remains constant throughout. This results in the parabolic shape for the test error.
#
# Bayes error: This is constant.

# %% [markdown]
# ## 2.4.7(a), (c)

# %% [markdown]
# The table below provides a training data set containing six observations, three predictors, and one qualitative response variable. (coded into vectors)

# %%
x_1 = np.array((0,2,0,0,-1,1))
x_2 = np.array((3,0,1,1,0,1))
x_3 = np.array((0,0,3,2,1,1))
y = ["Red", "Red","Red","Green","Green","Red"]

# %% [markdown]
# Suppose we wish to use this data set to make a prediction for Y when X1 = X2 = X3 = 0 using K-nearest neighbors.
#
# a) Compute the Euclidean distance between each observation and the test point, X1 = X2 = X3 = 0.

# %%
test_0 = [0,0,0,0,0,0]
dist1 = np.linalg.norm(x_1 - test_0)
dist2 = np.linalg.norm(x_2 - test_0)
dist3 = np.linalg.norm(x_3 - test_0)

print(dist1, dist2, dist3)
# Out:
# 2.449489742783178 3.4641016151377544 3.872983346207417

# %% [markdown]
# c) What is our prediction with K = 3? Why?

# %%
#taken from https://www.w3schools.com/python/python_ml_knn.asp

from sklearn.neighbors import KNeighborsClassifier

data = list(zip(x_1,x_2,x_3))
knn = KNeighborsClassifier(n_neighbors=3)

knn.fit(data, y)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
new_1 = 2
new_2 = 0
new_3 = 0
new_point = [(new_1,new_2,new_3)]

prediction = knn.predict(new_point)
prediction
# Out:
# array(['Red'], dtype='<U5')

# %% [markdown]
# When given an existing point such as above, it identified the correct data type.

# %% [markdown]
# ## 2.4.8(a) - (g)

# %%
college = pd.read_csv("College.csv")
college.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %%
college2 = pd.read_csv('College.csv', index_col =0)
college3 = college.rename ({'Unnamed: 0': 'College '}, axis =1)
college3 = college3.set_index('College ')

# %%
college2.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
#                               Room.Board  Books  Personal  PhD  Terminal  \
# ...

# %%
college3.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %%
college = college3

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
df = pd.DataFrame()
df["Apps"] = college["Apps"] 
df["Enroll"] = college["Enroll"] 
df["Top10perc"] = college["Top10perc"] 

pd.plotting.scatter_matrix(df)
# Out:
# array([[<AxesSubplot:xlabel='Apps', ylabel='Apps'>,
#         <AxesSubplot:xlabel='Enroll', ylabel='Apps'>,
#         <AxesSubplot:xlabel='Top10perc', ylabel='Apps'>],
#        [<AxesSubplot:xlabel='Apps', ylabel='Enroll'>,
#         <AxesSubplot:xlabel='Enroll', ylabel='Enroll'>,
#         <AxesSubplot:xlabel='Top10perc', ylabel='Enroll'>],
#        [<AxesSubplot:xlabel='Apps', ylabel='Top10perc'>,
#         <AxesSubplot:xlabel='Enroll', ylabel='Top10perc'>,
#         <AxesSubplot:xlabel='Top10perc', ylabel='Top10perc'>]],
#       dtype=object)

# %%
college['Elite'] = pd.cut(college['Top10perc'],[0,50,100], labels =['No', 'Yes'])

# %%
college["Elite"].value_counts()
# Out:
# No     699
# Yes     78
# Name: Elite, dtype: int64

# %%
#asked in chatgpt

plt.figure(figsize=(10, 6))
sns.boxplot(x='Elite', y='Outstate', data=college)
plt.title('Side-by-Side Boxplot of Outstate vs Elite')
plt.xlabel('Elite')
plt.ylabel('Outstate')
plt.show()

# %%
col = college.select_dtypes(include='number').columns.tolist()

for variable in col:
    plt.figure(figsize=(8, 6))
    college[variable].plot.hist(bins=5)
    plt.title('Histogram of {variable} with 5 Bins')
    plt.xlabel(variable)
    plt.ylabel('Frequency')
    plt.grid(axis='y', alpha=0.75)
    plt.show()

# %% [markdown]
# ## 2.4.9

# %%
auto = pd.read_csv("Auto.csv")
auto = auto.replace('?', np.nan)
auto = auto.dropna()
auto['horsepower'] = auto['horsepower'].astype(str).astype(int)
auto.head(20)
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0   18.0          8         307.0         130    3504          12.0    70
# 1   15.0          8         350.0         165    3693          11.5    70
# 2   18.0          8         318.0         150    3436          11.0    70
# 3   16.0          8         304.0         150    3433          12.0    70
# 4   17.0          8         302.0         140    3449          10.5    70
# 5   15.0          8         429.0         198    4341          10.0    70
# 6   14.0          8         454.0         220    4354           9.0    70
# 7   14.0          8         440.0         215    4312           8.5    70
# 8   14.0          8         455.0         225    4425          10.0    70
# 9   15.0          8         390.0         190    3850           8.5    70
# 10  15.0          8         383.0         170    3563          10.0    70
# 11  14.0          8         340.0         160    3609           8.0    70
# ...

# %%
auto.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower        int32
# weight            int64
# acceleration    float64
# year              int64
# origin            int64
# name             object
# dtype: object

# %% [markdown]
# All variables except the variable 'name' are quantitative.

# %%
auto.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration        year      origin
# count    392.000000  392.000000  392.000000
# mean      15.541327   75.979592    1.576531
# std        2.758864    3.683737    0.805518
# min        8.000000   70.000000    1.000000
# 25%       13.775000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# ...

# %% [markdown]
# This gives the minimum and maximum of each quantitative variable, as well as the mean and standard deviation.

# %%
auto_removed = auto.drop(index=auto.index[10:86]).reset_index(drop=True)
auto_removed.describe()
# Out:
#               mpg   cylinders  displacement  horsepower      weight  \
# count  316.000000  316.000000    316.000000  316.000000   316.00000
# mean    24.407595    5.373418    187.512658  100.848101  2936.53481
# std      7.863285    1.654179    100.114616   35.954147   811.87445
# min     11.000000    3.000000     68.000000   46.000000  1649.00000
# 25%     18.000000    4.000000    100.250000   75.000000  2213.75000
# 50%     23.950000    4.000000    145.500000   90.000000  2792.50000
# 75%     30.550000    6.000000    250.000000  115.000000  3508.00000
# max     46.600000    8.000000    455.000000  230.000000  4997.00000
#
#        acceleration        year      origin
# count    316.000000  316.000000  316.000000
# mean      15.717405   77.136076    1.601266
# std        2.713876    3.123464    0.819910
# min        8.500000   70.000000    1.000000
# 25%       14.000000   75.000000    1.000000
# 50%       15.500000   77.000000    1.000000
# ...

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(auto, alpha=0.8, figsize=(10, 10), diagonal='hist')
plt.show()

# %% [markdown]
# Some interesting relationships can be seen, with linear plots for a lot of the variables. To predict mpg we can use displacement, horsepower and weight, because these have linear relationships with mpg.
